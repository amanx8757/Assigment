# %%
 1. Discuss String Slicing and Provide Examples.

String slicing in Python is used to extract a specific
part of a string by specifying a range of indices.
The basic syntax is string[start:stop:step].

Example:
         string[start:stop:step]

start: The starting index (inclusive).
stop: The stopping index (exclusive).
step: The interval at which characters are selected.


2.Explain the Key Features of Lists in Python.

Ordered: Items in a list have a specific order.
Mutable: You can modify elements after the list is created.
Heterogeneous: Lists can contain elements of different data types.
Dynamic Size: Lists grow or shrink in size as needed.
Indexed Access: Elements can be accessed via an index starting from 0.

Example:

 my_list = [1, 'hello', 3.14]
print(my_list[1])  # Output: hello

3.Describe How to Access, Modify, and Delete Elements in a List with Examples

  a. Accessing Elements:

You can access elements using their index.
my_list = [10, 20, 30, 40]
print(my_list[2])  # Output: 30

  b.Modifying Elements:

python
my_list[2] = 99
print(my_list)  # Output: [10, 20, 99, 40]

Deleting Elements:
Use del, remove(), or pop() to delete elements.

del my_list[2]  # Deletes the element at index 2
print(my_list)  # Output: [10, 20, 40]

my_list.remove(20)  # Removes the first occurrence of 20
print(my_list)  # Output: [10, 40]

my_list.pop(1)  # Removes and returns element at index 1
print(my_list)  # Output: [10]


4. Compare and Contrast Tuples and Lists with Examples.

 A.  Lists is Mutable	and its
Syntax is	[] (square brackets)
# List Example
my_list = [1, 2, 3]
my_list[1] = 99
print(my_list)  # Output: [1, 99, 3]


B. Tuple is Immutable  and its syntax
  is () (parentheses)
# Tuple Example
my_tuple = (1, 2, 3)
# my_tuple[1] = 99  # This will raise an error because tuples are immutable.

5. Describe the Key Features of Sets and Provide Examples of Their Use.

Unordered: Sets do not maintain order.
Unique Elements: Sets automatically remove duplicates.
Mutable: Sets are mutable, but their elements must be immutable.
No Indexing: You can't access set elements using indices.

Examples:

my_set = {1, 2, 2, 3}
print(my_set)  # Output: {1, 2, 3}



6. Discuss the Use Cases of Tuples and Sets in Python Programming
Tuples:
Useful when you need an immutable sequence of values.
Commonly used for function return values or data integrity.

coordinates = (10.0, 20.0)  # Coordinates should not be changed


Ideal for membership testing and removing duplicates.
Sets are faster than lists for checking if an element is present.
Example Use Case for Sets:

unique_items = set([1, 2, 2, 3, 4])
print(unique_items)  # Output: {1, 2, 3, 4}


 7.  Describe How to Add, Modify, and Delete Items in a Dictionary with
Examples.

Adding:
my_dict = {'name': 'John', 'age': 25}
my_dict['city'] = 'New York'  # Adding new key-value pair
print(my_dict)  # Output: {'name': 'John', 'age': 25, 'city': 'New York'}

Modifying Items:
my_dict['age'] = 26  # Modifying the value of 'age'
print(my_dict)  # Output: {'name': 'John', 'age': 26, 'city': 'New York'}

Deleting Items:
del my_dict['city']  # Deleting key 'city'
print(my_dict)  # Output: {'name': 'John', 'age': 26}

my_dict.pop('age')  # Using pop() to delete 'age'
print(my_dict)  # Output: {'name': 'John'}

 8. Discuss the Importance of Dictionary Keys Being Immutable and
Provide Examples In Python, dictionary keys must be
immutable (like strings, numbers, or tuples).
This ensures that the hash value of a key remains
consistent, allowing for fast lookups.

Examples:

my_dict = {1: 'one', 'name': 'John', (10, 20): 'coordinates'}
# Keys must be immutable; hence lists or sets can't be used as keys.
# my_dict[[1, 2]] = 'invalid'  # This will raise an error

Immutable keys allow dictionaries to use a hash table for efficient searching
and indexing.Without immutability, dictionary lookups would be unreliable.
